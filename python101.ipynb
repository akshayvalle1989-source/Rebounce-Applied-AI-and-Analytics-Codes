# %% [markdown]
# <a href="https://colab.research.google.com/github/akshayvalle1989-source/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/python101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting

# %%
#The Introduction Card
name="akshay"
city="visakhapatnam"
year_of_birth=1999
current_year=2026
age=current_year-year_of_birth
print(f"Hello! My name is {name}, I'm {age} years old and I'm from {city}.")
# Out:
# Hello! My name is akshay, I'm 27 years old and I'm from visakhapatnam.

# %%
#grocery haul
bread=40
milk=65.50
eggs=120
total = bread+ milk + eggs
average_price = total/ 3
print(f"Total Price: ₹{total:.2f}")
print(f"Average Price per Item: ₹{average_price:.2f}")
# Out:
# Total Price: ₹225.50
# Average Price per Item: ₹75.17

# %%
#computing the number as even or odd
number = int(input("enter any digit:"))
is_even = number % 2 == 0
print(f"Number: {number}")
print(f"Is Even: {is_even}")
# Out:
# enter any digit:33
# Number: 33
# Is Even: False

# %% [markdown]
# # **Password Strength Check:**

# %%
#password
password = input("Enter a password: ")
length_ok = len(password) >= 8
contains_at = '@' in password
is_strong = length_ok and contains_at
print(f"Password: {password}")
print(f"Length OK (>= 8): {length_ok}")
print(f"Contains '@': {contains_at}")
print(f"Strong: {is_strong}")
# Out:
# Enter a password: @apple123
# Password: @apple123
# Length OK (>= 8): True
# Contains '@': True
# Strong: True

# %% [markdown]
# # **Currency Converter:**

# %%
# currency_converter
inr=75000
yen=inr*1.75
print(f"INR: '{inr}' amounts to JPY '{yen:.2f}'")
# Out:
# INR: '75000' amounts to JPY '131250.00'

# %% [markdown]
# # **Class Roster**

# %%
attendees=["a","c","b","d","e","f","g","h"]
total=len(attendees)
print(f"total attendees: {total}")
print("firstname:",attendees[0])
print("last 2 names:",attendees[-2:])
print("first 3 attendees:",sorted(attendees[:3]))
# Out:
# total attendees: 8
# firstname: a
# last 2 names: ['g', 'h']
# first 3 attendees: ['a', 'b', 'c']

# %%
team={"a":1234,"b":5678,"c":9876,"d":2335,"e":1253}
print(f"phone number of employee a:{team["a"]}")
team["f"]=3245
print(f"updated team:{team}")
print("length of team:",len(team),"pax")
# Out:
# phone number of employee a:1234
# updated team:{'a': 1234, 'b': 5678, 'c': 9876, 'd': 2335, 'e': 1253, 'f': 3245}
# length of team: 6 pax

# %%
s=[x**2 for x in range(1,21)if x%2==0]
print(f"even squares:{s}")
# Out:
# even squares:[4, 16, 36, 64, 100, 144, 196, 256, 324, 400]

# %%
products = [
("Notebook", 250),
("Pen", 20),
("Backpack", 1800),
("Eraser", 15),
("Water Bottle", 350),
]
print(sorted(products,key=lambda p:p[0]))
print(sorted(products,key=lambda p:p[1]))
# Out:
# [('Backpack', 1800), ('Eraser', 15), ('Notebook', 250), ('Pen', 20), ('Water Bottle', 350)]
# [('Eraser', 15), ('Pen', 20), ('Notebook', 250), ('Water Bottle', 350), ('Backpack', 1800)]

# %%
scores = {
"Anika": 35,
"Rohan": 72,
"Meera": 40,
"Kabir": 28,
"Diya": 88,
"Ishaan": 55,
}
passed = list(map(lambda item: item[0],
                           filter(lambda item: item[1] >= 40, scores.items())))

print("Passing Students:")
print(passed)
# Out:
# Passing Students:
# ['Rohan', 'Meera', 'Diya', 'Ishaan']
